# %%
import numpy as np
import matplotlib.pyplot as plt
import STOM_higgs_tools

# %%
vals = STOM_higgs_tools.generate_data()
bin_heights, bin_edges, patches = plt.hist(vals, range = [104, 155], bins = 30)
plt.show()

# %%
5*5
# Out:
# 25

# %%
plt.contour([A,lambda],chi2)
